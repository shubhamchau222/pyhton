# %%
import pyodbc # for connecting Sql server management Studio 
import mysql.connector as connector

# %%
#db = connector.connect(host='localhost', user='username',  )

# %%
conn.close()

# %%
# connecting the database server
conn = pyodbc.connect('Driver={SQL Server};' 
                      'Server=PC1\MSSQLSERVER01;'
                      'Database=practice;'
                      'Trusted_Connection=yes;')
# conn.is_connected() ---->AttributeError: 'pyodbc.Connection' object has no attribute 'is_connected'

# %%
cursor = conn.cursor()

# %%
query1 = "INSERT INTO dbo.StudentDetails VALUES ('shguygjjav','Kumar','1997-11-11','Eleventh','A')"
query2 ="select * from dbo.StudentDetails "

# %%
 #inserting data into database 
cursor.execute(query1 )
cursor.commit()  # it's necessory to make changes

# %%
# you can use commit () single time also 
cursor.commit()

# %%
b=cursor.execute(query2)

# %%
# here b is the cursor object 
print(b)
print(type (b))
# Out:
# ...
# <class 'pyodbc.Cursor'>

# %%
for i in b:
    print(i)
# Out:
# (6, 'Sachin', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (7, 'Sachin', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (8, 'Sachin', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (9, 'Sachin', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (10, 'Sachin', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (17, 'rakesh', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (18, 'uday', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (19, 'uday', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (20, 'uday', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (21, 'uday', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (22, 'shguygjjav', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (23, 'shguygjjav', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (24, 'shguygjjav', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (25, 'shguygjjav', 'Kumar', '1997-11-11', 'Eleventh', 'A')
# (26, 'shguygjjav', 'Kumar', '1997-11-11', 'Eleventh', 'A')

# %% [markdown]
# # insert csv file data into the database

# %%
# connecting the database server

# conn.is_connected() ---->AttributeError: 'pyodbc.Connection' object has no attribute 'is_connected'
try:
    conn = pyodbc.connect('Driver={SQL Server};' 
                      'Server=PC1\MSSQLSERVER01;'
                      'Database=practice;'
                      'Trusted_Connection=yes;')
    #cursor creation 
    cursor = conn.cursor()
except Exception as e:
    print("Sorry...! , connection failed...")
    print(str(e))

# %% [markdown]
# ###  load & read the csv file .

# %%
with open(file=r'F:\MY SQL NOTES _ineuron\19.2.MySQL\Imp files\glass.csv' , mode="r") as f:  # give complete file path 
        
        glass_data = csv.reader(f, delimiter="\n")
        for line in enumerate(glass_data):
            for list_ in (line[1]):
                print(list_)
# Out:
# index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
l=[]
with open(file=r'F:\MY SQL NOTES _ineuron\19.2.MySQL\Imp files\glass.csv' , mode="r") as f:  # give complete file path 
    next(f)
    reader = csv.reader(f , delimiter ="\n")
    for i in reader:
        l.append(i)
        print(i)
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %% [markdown]
# ## create table in database

# %%
## to close the connection
conn.close()
print("connection closed successfully ........")
# Out:
# connection closed successfully ........

# %%
# connecting the database server

# conn.is_connected() ---->AttributeError: 'pyodbc.Connection' object has no attribute 'is_connected'
try:
    conn = pyodbc.connect('Driver={SQL Server};' 
                      'Server=PC1\MSSQLSERVER01;'
                      'Database=practice;'
                      'Trusted_Connection=yes;')
    #cursor creation 
    cursor = conn.cursor()
    print("connection Succesfull with database {} ....".format('\t practice'))
except Exception as e:
    print("Sorry...! , connection failed...")
    print(str(e))
# Out:
# connection Succesfull with database 	 practice ....

# %%
# create table Query

query ='''if not exists (select * from sysobjects where name = 'glassdata' and xtype ='U')
                                           create table glassdata 
                                              ( 
                                                         id int primary key identity(1,1),
                                                                        index_ int ,
                                                                                 RI float,Na float,Mg float,Al float, Si  float ,K float ,       
                                                                                                        Ca  float, Ba  float,Fe  float, Class int
                                                )'''

# %%
####  create table 
cursor.execute(query)
cursor.commit()
print("Table created successfully .........")
print("query commited ")
# Out:
# Table created successfully .........
# query commited

# %%
# example of format method 
print( "values({values})".format(values="shubham" ))
# Out:
# values(shubham)

# %% [markdown]
# ## uploading csv data to the Sql server database

# %%
#### adding the csv data into the table
with open(file=r'F:\MY SQL NOTES _ineuron\19.2.MySQL\Imp files\glass.csv' , mode="r") as f:  # give complete file path 
    next(f)
    reader = csv.reader(f , delimiter ="\n")
    for i in reader:
        for x in i :
            cursor.execute("insert into glassdata values({values})".format(values=x))
            
cursor.commit()

# %%
conn.close()

# %% [markdown]
# # fetching data from sql server & make dataframe

# %%
import pandas as pd 
import pyodbc

# %%
conn.close()

# %%
try:
    conn = pyodbc.connect('Driver={SQL Server};' 
                      'Server=PC1\MSSQLSERVER01;'
                      'Database=practice;'
                      'Trusted_Connection=yes;')
    #cursor creation 
    cursor = conn.cursor()
    print("connection Succesfull with database {} ....".format('\t practice'))
except Exception as e:
    print("Sorry...! , connection failed...")
    print(str(e))
# Out:
# connection Succesfull with database 	 practice ....

# %%
data_list=[]
query = "select * from glassdata "
cursor= cursor.execute(query)
for i in enumerate(cursor.fetchall()):
        data_list.append ( list (i[1]) )      # bydefault type= pyodbc.Row
        # hence , we need to convert it into the list

# %%
dataframe = pd.DataFrame(data_list)
dataframe.columns = ['id' , 'index','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Class']

# %%
dataframe.head()
# Out:
#    id  index       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0   1      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1   2      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2   3      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3   4      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4   5      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %% [markdown]
#         if dataframe.index.nunique() is dataframe.shape[0] :
#              print("you can safely remove it ")

# %%
if "index" in dataframe.columns:
    dataframe.drop(["index"] , axis=1 ,inplace=True )
    print("column {column_name}  is deleted successfully.... " .format(column_name ="index" ))
# Out:
# column index  is deleted successfully....

# %%
dataframe.head()
# Out:
#    id       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
import missingno as msn
msn.bar(dataframe , color='#ff0000' , figsize=(14, 5) )
print("no any null values ......")
# Out:
# no any null values ......

# %% [markdown]
# ##  Json data

# %%
import json

# %%
with open(r"F:\Webscraping\disney_raw_data.json" , encoding="utf8") as f :
    file = json.load(f)
    json_data_list = []  # to store the json data 
    for  i in file:
        json_data_list.append(i)

# %%
str( json_data_list[1] )
# Out:
# "{'title': 'Snow White and the Seven Dwarfs', 'Directed by': ['David Hand (supervising)', 'William Cottrell', 'Wilfred Jackson', 'Larry Morey', 'Perce Pearce', 'Ben Sharpsteen'], 'Produced by': 'Walt Disney', 'Written by': ['Ted Sears', 'Richard Creedon', 'Otto Englander', 'Dick Rickard', 'Earl Hurd', 'Merrill De Maris', 'Dorothy Ann Blank', 'Webb Smith'], 'Based on': ['Snow White', 'by The', 'Brothers Grimm'], 'Starring': ['Adriana Caselotti', 'Lucille La Verne', 'Harry Stockwell', 'Roy Atwell', 'Pinto Colvig', 'Otis Harlan', 'Scotty Mattraw', 'Billy Gilbert', 'Eddie Collins', 'Moroni Olsen', 'Stuart Buchanan'], 'Music by': ['Frank Churchill', 'Paul Smith', 'Leigh Harline'], 'Production company': 'Walt Disney Productions', 'Distributed by': 'RKO Radio Pictures', 'Release date': ['December 21, 1937 ( Carthay Circle Theatre , Los Angeles , CA , premiere)'], 'Running time': '83 minutes', 'Country': 'United States', 'Language': 'English', 'Budget': '$1.49 million', 'Box office': '$418 m
# ...

# %% [markdown]
# ##### now we try to insert data into the Sql server

# %%
for i in json_data_list:
    print(i)
# Out:
# {'title': 'Academy Award Review of', 'Production company': 'Walt Disney Productions', 'Release date': ['May 19, 1937'], 'Running time': '41 minutes (74 minutes 1966 release)', 'Country': 'United States', 'Language': 'English', 'Box office': '$45.472'}
# ...

# %%
conn.close()
print("connection closed .......")
# Out:
# connection closed .......

# %%
# connecting the database server

# conn.is_connected() ---->AttributeError: 'pyodbc.Connection' object has no attribute 'is_connected'
try:
    conn = pyodbc.connect('Driver={SQL Server};' 
                      'Server=PC1\MSSQLSERVER01;'
                      'Database=practice;'
                      'Trusted_Connection=yes;')
    #cursor creation 
    cursor = conn.cursor()
    print("connection Succesfull with database {} ....".format('\t practice'))
except Exception as e:
    print("Sorry...! , connection failed...")
    print(str(e))
# Out:
# connection Succesfull with database 	 practice ....

# %%
query  =''' if not exists (select * from sysobjects where name = 'disney_raw_data' and xtype='U' )
                  create table disney_raw_data 
                            (
                                    id int primary key identity(1,1)  ,
                                    movie_data nvarchar(max)
                            ) '''

# %%
# create table 
cursor.execute(query)
print("table created....")
cursor.commit()
# Out:
# table created....

# %%
z ="{'title': 'Academy Award Review of', 'Production company': 'Walt Disney Productions', 'Release date': ['May 19, 1937'], 'Running time': '41 minutes (74 minutes 1966 release)', 'Country': 'United States', 'Language': 'English', 'Box office': '$45.472'}"

# %%
#replacing ' ' by " "
s = z.replace("\'", '\"')

# %%
s
# Out:
# '{"title": "Academy Award Review of", "Production company": "Walt Disney Productions", "Release date": ["May 19, 1937"], "Running time": "41 minutes (74 minutes 1966 release)", "Country": "United States", "Language": "English", "Box office": "$45.472"}'

# %%
json_data_list_filtered=[]
for i in json_data_list : 
    print(str(i).replace("\'", '\"'))
    json_data_list_filtered.append( str(i).replace("\'", '\"')      )
    print("\n"*2)
# Out:
# {"title": "Academy Award Review of", "Production company": "Walt Disney Productions", "Release date": ["May 19, 1937"], "Running time": "41 minutes (74 minutes 1966 release)", "Country": "United States", "Language": "English", "Box office": "$45.472"}
#
#
#
# ...

# %%
# conn.is_connected() ---->AttributeError: 'pyodbc.Connection' object has no attribute 'is_connected'
try:
    conn = pyodbc.connect('Driver={SQL Server};' 
                      'Server=PC1\MSSQLSERVER01;'
                      'Database=practice;'
                      'Trusted_Connection=yes;')
    #cursor creation 
    cursor = conn.cursor()
    print("connection Succesfull with database {} ....".format('\t practice'))
except Exception as e:
    print("Sorry...! , connection failed...")
    print(str(e))
# Out:
# connection Succesfull with database 	 practice ....

# %%
for i in json_data_list_filtered:
    cursor.execute(""" insert into disney_raw_data  values """)

# %% [markdown]
# ##### doubts
# ### cursor.execute(""" insert into disney_raw_data  values({value})""".format(value = 'applicable'))

# %%
conn.commit()
conn.close()

# %%
json_data_list_filtered[3]
# Out:
# '{"title": "Fantasia", "Directed by": ["Samuel Armstrong", "James Algar", "Bill Roberts", "Paul Satterfield", "Ben Sharpsteen", "David D. Hand", "Hamilton Luske", "Jim Handley", "Ford Beebe", "T. Hee", "Norman Ferguson", "Wilfred Jackson"], "Produced by": ["Walt Disney", "Ben Sharpsteen"], "Story by": ["Joe Grant", "Dick Huemer"], "Starring": ["Leopold Stokowski", "Deems Taylor"], "Narrated by": "Deems Taylor", "Music by": "See program", "Cinematography": "James Wong Howe", "Production company": "Walt Disney Productions", "Distributed by": "RKO Radio Pictures", "Release date": ["November 13, 1940"], "Running time": "126 minutes", "Country": "United States", "Language": "English", "Budget": "$2.28 million", "Box office": "$76.4–$83.3 million"}'
